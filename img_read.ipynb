# %% [markdown]
# <a href="https://colab.research.google.com/github/mjvnc37/DataScince-in-python/blob/main/img_read.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdriv')
# Out:
# Mounted at /content/gdriv

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img=plt.imread('/content/gdriv/MyDrive/datasets/t.jfif')
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
