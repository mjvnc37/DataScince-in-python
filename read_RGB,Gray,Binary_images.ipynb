# %% [markdown]
# <a href="https://colab.research.google.com/github/mjvnc37/DataScince-in-python/blob/main/read_RGB%2CGray%2CBinary_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import PIL
import matplotlib.pyplot as plt
img=PIL.Image.open("/content/drive/MyDrive/Photos /Beauty Cam_20221023213320043_save.jpg")
gray_img=img.convert('RGBA')
plt.imshow(gray_img,cmap='gray')

# %%
from PIL import Image
img=Image.open(r"/content/drive/MyDrive/Photos /Beauty Cam_20221023213320043_save.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1047x1920 at 0x7FEA5476FDF0>
